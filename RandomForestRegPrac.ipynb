# %% [markdown]
# Predicting Salary - Truth of Bluff

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')

X = dataset.iloc[:, 1: -1].values
y = dataset.iloc[:, -1].values

# %%
# we dont use the splitting ,bcz we use all data and other issue is less data

# %% [markdown]
# Training random forest regression model using whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor

# n_estimator - no. of trees (in the forest , whole dataset)
regressor = RandomForestRegressor(n_estimators= 10, random_state= 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# Predicting a new dataset

# %%
# Predict requires 2D array
regressor.predict([[6.5]])
# Out:
# array([167000.])

# %% [markdown]
# Visualizing (Higher resolutiom)

# %%
# Takes from poly code


X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Decision Tree reg)')
plt.xlabel ('Position level')
plt.ylabel('salary')
plt.show()
# Out:
# <ipython-input-14-ed02fa19c156>:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)
